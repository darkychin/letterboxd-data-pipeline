# %% [markdown]
# # Bronze - Actors - Column Characters Frequency Explore

# %%
import pandas as pd
import plotly.express as px
from letterboxd_data_pipeline.load_data import load_files_from_layer
from letterboxd_data_pipeline.explore_data.char_frequency import gen_char_frequency_df

bronze_df = load_files_from_layer(layer="bronze", file_list=["actors.parquet"])
target_df = bronze_df["actors"]
# Out:
# Start loading data...
# Loading: data/bronze/actors.parquet
# Done!
# Finish loading.

# %%
target_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5798450 entries, 0 to 5798449
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id      object
#  1   name    object
#  2   role    object
# dtypes: object(3)
# memory usage: 132.7+ MB

# %% [markdown]
# ## Column "name"

# %%
df = gen_char_frequency_df(target_df["name"])
df_head = df.head(100)
df_tail = df.tail(1000)

# %%
fig = px.bar(x=df_head["character"], y =df_head["frequency"])
fig.show()

# %%
fig_tail = px.bar(x=df_tail["character"], y =df_tail["frequency"])
fig_tail.show()

# %%
# pattern = r"[^\p{L}\p{M}\s\-\']+" // required library "regex"
pattern = r"[^\w\x00-\x7F]"

special_char_df = df[df["character"].str.contains(pattern, regex=True)]
special_char_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 65 to 2378
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   character  93 non-null     object
#  1   frequency  93 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
fig_symbol = px.bar(x=special_char_df["character"], y=special_char_df["frequency"])
fig_symbol.show()

# %%
pd.set_option('display.max_rows', None)
special_char_df
# Out:
#      character  frequency
# 65           ̇       3349
# 107          ’        876
# 151          ”        225
# 152          «        225
# 153          »        225
# 156          “        211
# 158          ́        204
# 190          ิ        147
# 206          ั        115
# 214          ์        102
# 228                    87
# 232          ‘         85
# 233          ﻿         84
# 257          ุ         66
# 262          ̄         59
# 293          ​         44
# 309          ·         39
# 311          ่         39
# 330          „         35
# 334          ̈         34
# 337          ี         33
# 343          ้         32
# 349          ­         31
# 414          ̣         21
# 441          ´         20
# 460          ู         19
# 463          ‎         19
# 480          –         17
# 506          ‏         16
# 532          ̃         15
# 549          ・         14
# 624          ื         11
# 659          ̧         11
# 688          ）         10
# ...

# %%
pd.reset_option('display.max_rows')

# %%
target_df_no_na_df = target_df.dropna()
target_df_no_na_df[target_df_no_na_df["name"].str.contains(r"«")]
# Out:
#               id                           name                role
# 274458   1007214         José «Saza» Sazatornil       Administrator
# 428390   1013333         José «Saza» Sazatornil  Corporal Gutiérrez
# 440248   1013848       Pedro «Pedrucho» Basauri        Il "Maestro"
# 462070   1014832        Alberto «Atabar» Pedret         Voz locutor
# 526811   1017848  Gabriel «Chino» Marín Catalán           El Escape
# ...          ...                            ...                 ...
# 5629554  1850284          Alain « Al1 » Clément             guitars
# 5629558  1850284          Steeve « Zuul » Petit         Lead vocals
# 5680436  1873902            Josep «Kitflus» Mas            Teclados
# 5691525  1879131  Enrique Villareal «El Drogas»          Voz y bajo
# 5691526  1879131        Javier «Boni» Hernández      Voz y guitarra
#
# [179 rows x 3 columns]

# %%
target_df_no_na_df[target_df_no_na_df["name"].str.contains(r"℃")]
# Out:
# Empty DataFrame
# Columns: [id, name, role]
# Index: []

# %% [markdown]
# ## Column "role"

# %%
df = gen_char_frequency_df(target_df["role"])
df_head = df.head(100)
df_tail = df.tail(1000)

# %%
fig = px.bar(x=df_head["character"], y =df_head["frequency"])
fig.show()

# %%
fig_tail = px.bar(x=df_tail["character"], y =df_tail["frequency"])
fig_tail.show()

# %%
# pattern = r"[^\p{L}\p{M}\s\-\']+" // required library "regex"
pattern = r"[^\w\x00-\x7F]"

special_char_df = df[df["character"].str.contains(pattern, regex=True)].reset_index(drop=True)
special_char_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   character  159 non-null    object
#  1   frequency  159 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.6+ KB

# %%
special_char_df
# Out:
#     character  frequency
# 0           ’       2337
# 1           «       1006
# 2           »        998
# 3           –        873
# 4           ̇        789
# ..        ...        ...
# 154         ី          1
# 155         ិ          1
# 156         ូ          1
# 157         ★          1
# 158         ်          1
#
# [159 rows x 2 columns]

# %%
fig = px.bar(x=special_char_df["character"], y =special_char_df["frequency"])
fig.show()
